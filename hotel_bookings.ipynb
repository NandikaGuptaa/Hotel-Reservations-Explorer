# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading data from a csv file
data = pd.read_csv('hotel_booking.csv')

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
# getting basic information about data
data.shape
# Out:
# (119390, 36)

# %%
pd.set_option('display.max_columns',36)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
# getting number of unique values in each column
data.nunique()
# Out:
# hotel                                  2
# is_canceled                            2
# lead_time                            479
# arrival_date_year                      3
# arrival_date_month                    12
# arrival_date_week_number              53
# arrival_date_day_of_month             31
# stays_in_weekend_nights               17
# stays_in_week_nights                  35
# adults                                14
# children                               5
# babies                                 5
# meal                                   5
# country                              177
# market_segment                         8
# distribution_channel                   5
# is_repeated_guest                      2
# previous_cancellations                15
# previous_bookings_not_canceled        73
# reserved_room_type                    10
# assigned_room_type                    12
# booking_changes                       21
# deposit_type                           3
# ...

# %%
# unique values in 'hotel' column
data['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
# getting count of uniques value from different columns
data['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
data['meal'].value_counts()
# Out:
# meal
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: count, dtype: int64

# %%
data['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
data['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
data['deposit_type'].value_counts()
# Out:
# deposit_type
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: count, dtype: int64

# %%
data['customer_type'].value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
type(data['reservation_status_date'])
# Out:
# pandas.core.series.Series

# %%
# converting data type of 'reservation_status_date' column to datetime 
data['reservation_status_date'] = pd.to_datetime(data['reservation_status_date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.482918     106.863097           0.707476
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
data.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
# finding null values
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# replacing null values with 0
data.fillna(0 , inplace = True)

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# combining "undefined" and "SC" meals as one due to their same meaning
data['meal'].replace('Undefined' , 'SC' , inplace = True)
# Out:
# C:\Users\Nandika\AppData\Local\Temp\ipykernel_8748\1776250534.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['meal'].replace('Undefined' , 'SC' , inplace = True)

# %%
data['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC'], dtype=object)

# %%
# checking invalid entries w.r.t adults, children, babies count
invalid_data = data[(data['adults'] == 0) & (data['children'] == 0) & (data['babies'] == 0)]
invalid_data[['adults' , 'children' , 'babies']]
# Out:
#         adults  children  babies
# 2224         0       0.0       0
# 2409         0       0.0       0
# 3181         0       0.0       0
# 3684         0       0.0       0
# 3708         0       0.0       0
# ...        ...       ...     ...
# 115029       0       0.0       0
# 115091       0       0.0       0
# 116251       0       0.0       0
# 116534       0       0.0       0
# 117087       0       0.0       0
#
# [180 rows x 3 columns]

# %%
delete_data = (data['adults'] == 0) & (data['children'] == 0) & (data['babies'] == 0)
delete_data
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119390, dtype: bool

# %%
# converting false values into true values for 'delete_data' and storing it as new_data
new_data = data[~delete_data]
new_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# hotel reservations count
sns.countplot(x = 'hotel' , data = new_data)
plt.title('Total Hotel Reservations')
plt.show()

# %%
# hotel wise cancelations
sns.countplot(x = 'hotel' , hue = 'is_canceled' , data = new_data)
plt.title('Reservation Count')
plt.show()

# %%
# total cancelations count
sns.countplot(x = 'is_canceled' , data = new_data)
plt.show()

# %%
# canceled and repeated guest analysis
sns.countplot(x = 'is_canceled' , data = new_data , hue = 'is_repeated_guest')
plt.show()

# %%
new_data['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
# getting data of guests hotel wise who didnot cancel their reservations
resort_hotel = new_data[(new_data['hotel'] == 'Resort Hotel') & (new_data['is_canceled'] == 0)]
city_hotel = new_data[(new_data['hotel'] == 'City Hotel') & (new_data['is_canceled'] == 0)]

# %%
resort_hotel.shape
# Out:
# (28927, 36)

# %%
city_hotel.shape
# Out:
# (46084, 36)

# %%
# finding the number of guests in resort hotel from each country
resort_hotel['country'].value_counts()
# Out:
# country
# PRT    10184
# GBR     5922
# ESP     3105
# IRL     1734
# FRA     1399
#        ...
# UGA        1
# COM        1
# MUS        1
# BIH        1
# SAU        1
# Name: count, Length: 119, dtype: int64

# %%
# finding the number of guests in city hotel from each country
city_hotel['country'].value_counts()
# Out:
# country
# PRT    10793
# FRA     7069
# DEU     5010
# GBR     3746
# ESP     3278
#        ...
# UGA        1
# PYF        1
# JAM        1
# SYC        1
# FRO        1
# Name: count, Length: 151, dtype: int64

# %%
# getting the combined guests data of both hotels who didnot cancel their reservations
booked_data = new_data[new_data['is_canceled'] == 0]

# %%
# Prices guest pay for a room per night
sns.barplot(x = 'reserved_room_type' , y = 'adr' , hue = 'hotel' , data = booked_data)
plt.title('Prices of Room Types per night')
plt.xlabel('Room Type')
plt.ylabel('Price')
plt.show()

# %%
# Prices guest pay for a room per night
sns.boxplot(x = 'reserved_room_type' , y = 'adr' , hue = 'hotel' , data = booked_data)
plt.title('Prices of Room Types per night')
plt.xlabel('Room Type')
plt.ylabel('Price')
plt.show()

# %%
# prices variation over the year for 'resort hotel' 
resort_hotel_price = resort_hotel.groupby(['arrival_date_month'])['adr'].mean().reset_index()
month_to_num = { 'January' : 1 , 'February' : 2 , 'March' : 3 , 'April' : 4 , 'May' : 5 , 'June' : 6 , 'July' : 7 , 'August' : 8 , 'September' : 9 , 'October' : 10 , 'November' : 11 , 'December' : 12}
resort_hotel_price['arrival_date_month'] = resort_hotel_price['arrival_date_month'].map(month_to_num) 
resort_hotel_price
# Out:
#     arrival_date_month         adr
# 0                    4   75.867816
# 1                    8  181.205892
# 2                   12   68.410104
# 3                    2   54.147478
# 4                    1   48.761125
# 5                    7  150.122528
# 6                    6  107.974850
# 7                    3   57.056838
# 8                    5   76.657558
# 9                   11   48.706289
# 10                  10   61.775449
# 11                   9   96.416860

# %%
resort_hotel_price.sort_values('arrival_date_month' , ascending = True , inplace = True)

# %%
resort_hotel_price
# Out:
#     arrival_date_month         adr
# 4                    1   48.761125
# 3                    2   54.147478
# 7                    3   57.056838
# 0                    4   75.867816
# 8                    5   76.657558
# 6                    6  107.974850
# 5                    7  150.122528
# 1                    8  181.205892
# 11                   9   96.416860
# 10                  10   61.775449
# 9                   11   48.706289
# 2                   12   68.410104

# %%
sns.barplot(x = 'arrival_date_month' , y = 'adr' , data = resort_hotel_price)
plt.title('ADR Per Month-Resort Hotel')
plt.xlabel('Month')
plt.ylabel('ADR')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# prices variation over the year for 'city hotel'
city_hotel_price = city_hotel.groupby(['arrival_date_month'])['adr'].mean().reset_index()
month_to_num = { 'January' : 1 , 'February' : 2 , 'March' : 3 , 'April' : 4 , 'May' : 5 , 'June' : 6 , 'July' : 7 , 'August' : 8 , 'September' : 9 , 'October' : 10 , 'November' : 11 , 'December' : 12}
city_hotel_price['arrival_date_month'] = city_hotel_price['arrival_date_month'].map(month_to_num) 
city_hotel_price
# Out:
#     arrival_date_month         adr
# 0                    4  111.962267
# 1                    8  118.674598
# 2                   12   88.401855
# 3                    2   86.520062
# 4                    1   82.330983
# 5                    7  115.818019
# 6                    6  117.874360
# 7                    3   90.658533
# 8                    5  120.669827
# 9                   11   86.946592
# 10                  10  102.004672
# 11                   9  112.776582

# %%
city_hotel_price.sort_values('arrival_date_month' , ascending = True , inplace = True)

# %%
city_hotel_price
# Out:
#     arrival_date_month         adr
# 4                    1   82.330983
# 3                    2   86.520062
# 7                    3   90.658533
# 0                    4  111.962267
# 8                    5  120.669827
# 6                    6  117.874360
# 5                    7  115.818019
# 1                    8  118.674598
# 11                   9  112.776582
# 10                  10  102.004672
# 9                   11   86.946592
# 2                   12   88.401855

# %%
sns.barplot(x = 'arrival_date_month' , y = 'adr' , data = city_hotel_price)
plt.title('ADR Per Month-City Hotel')
plt.xlabel('Month')
plt.ylabel('ADR')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
final_merged_hotels_adr = resort_hotel_price.merge(city_hotel_price , on = 'arrival_date_month')
final_merged_hotels_adr.columns = ['month' , 'ADR of Resort Hotel' , 'ADR of City Hotel']
final_merged_hotels_adr
# Out:
#     month  ADR of Resort Hotel  ADR of City Hotel
# 0       1            48.761125          82.330983
# 1       2            54.147478          86.520062
# 2       3            57.056838          90.658533
# 3       4            75.867816         111.962267
# 4       5            76.657558         120.669827
# 5       6           107.974850         117.874360
# 6       7           150.122528         115.818019
# 7       8           181.205892         118.674598
# 8       9            96.416860         112.776582
# 9      10            61.775449         102.004672
# 10     11            48.706289          86.946592
# 11     12            68.410104          88.401855

# %%
# meal preferences for both hotels
sns.countplot(x = 'meal' , hue = 'hotel' , data = new_data)
plt.title('Meal Preferences')
plt.show()

# %%
new_data['meal'].value_counts()
# Out:
# meal
# BB    92236
# HB    14458
# SC    11718
# FB      798
# Name: count, dtype: int64

# %%
x = new_data['meal'].value_counts().index
y = new_data['meal'].value_counts().values

# %%
# analyzing meal preferences percentages using pie chart 
plt.pie(y , labels = x , autopct = "%0.2f%%")
plt.show()

# %%
new_data['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56408
# Offline TA/TO    24182
# Groups           19791
# Direct           12582
# Corporate         5282
# Complementary      728
# Aviation           235
# Undefined            2
# Name: count, dtype: int64

# %%
# market segment vs weekend nights stays in both hotels
sns.boxplot(x = 'market_segment' , y = 'stays_in_weekend_nights' , hue = 'hotel' , data = new_data)
plt.title('Stays on Weekend Nights')
plt.xticks(rotation = 60)
plt.show()

# %%
# total special requests
sns.countplot(x = 'total_of_special_requests' , data = new_data)
plt.title('Total Special Requests')
plt.show()

# %%
# total special requests hotel wise
sns.countplot(x = 'total_of_special_requests' , hue = 'hotel' , data = new_data)
plt.title('Total Special Requests')
plt.show()

# %%
# guests per month in resort hotel to find which month was the busiest
busy_resort = resort_hotel['arrival_date_month'].value_counts().reset_index()
busy_resort.columns = ['month' , 'number of guests']
month_to_num = { 'January' : 1 , 'February' : 2 , 'March' : 3 , 'April' : 4 , 'May' : 5 , 'June' : 6 , 'July' : 7 , 'August' : 8 , 'September' : 9 , 'October' : 10 , 'November' : 11 , 'December' : 12}
busy_resort['month'] = busy_resort['month'].map(month_to_num) 
busy_resort
# Out:
#     month  number of guests
# 0       8              3257
# 1       7              3137
# 2      10              2575
# 3       3              2571
# 4       4              2550
# 5       5              2535
# 6       2              2308
# 7       9              2102
# 8       6              2037
# 9      12              2014
# 10     11              1975
# 11      1              1866

# %%
busy_resort.sort_values('month' , ascending = True , inplace = True)

# %%
busy_resort
# Out:
#     month  number of guests
# 11      1              1866
# 6       2              2308
# 3       3              2571
# 4       4              2550
# 5       5              2535
# 8       6              2037
# 1       7              3137
# 0       8              3257
# 7       9              2102
# 2      10              2575
# 10     11              1975
# 9      12              2014

# %%
sns.barplot(x = 'month' , y = 'number of guests' , data = busy_resort)
plt.title('Guests Per Month in Resort Hotel')
plt.show()

# %%
# guests per month in city hotel to find which month was the busiest
busy_city = city_hotel['arrival_date_month'].value_counts().reset_index()
busy_city.columns = ['month' , 'number of guests']
month_to_num = { 'January' : 1 , 'February' : 2 , 'March' : 3 , 'April' : 4 , 'May' : 5 , 'June' : 6 , 'July' : 7 , 'August' : 8 , 'September' : 9 , 'October' : 10 , 'November' : 11 , 'December' : 12}
busy_city['month'] = busy_city['month'].map(month_to_num) 
busy_city
# Out:
#     month  number of guests
# 0       8              5367
# 1       7              4770
# 2       5              4568
# 3       6              4358
# 4      10              4326
# 5       9              4283
# 6       3              4049
# 7       4              4010
# 8       2              3051
# 9      11              2676
# 10     12              2377
# 11      1              2249

# %%
busy_city.sort_values('month' , ascending = True , inplace = True)

# %%
busy_city
# Out:
#     month  number of guests
# 11      1              2249
# 8       2              3051
# 6       3              4049
# 7       4              4010
# 2       5              4568
# 3       6              4358
# 1       7              4770
# 0       8              5367
# 5       9              4283
# 4      10              4326
# 9      11              2676
# 10     12              2377

# %%
sns.barplot(x = 'month' , y = 'number of guests' , data = busy_city)
plt.title('Guests Per Month in City Hotel')
plt.show()

# %%
final_merged_busy_hotel = busy_resort.merge(busy_city , on = 'month')
final_merged_busy_hotel.columns = ['month' , 'no. of guests in resort hotel' , 'no. of guests in city hotel']
final_merged_busy_hotel
# Out:
#     month  no. of guests in resort hotel  no. of guests in city hotel
# 0       1                           1866                         2249
# 1       2                           2308                         3051
# 2       3                           2571                         4049
# 3       4                           2550                         4010
# 4       5                           2535                         4568
# 5       6                           2037                         4358
# 6       7                           3137                         4770
# 7       8                           3257                         5367
# 8       9                           2102                         4283
# 9      10                           2575                         4326
# 10     11                           1975                         2676
# 11     12                           2014                         2377

# %%
# analyzing how long people stay in the hotels
booked_data['total_nights_spend'] = booked_data['stays_in_week_nights'] + booked_data['stays_in_weekend_nights']
# Out:
# C:\Users\Nandika\AppData\Local\Temp\ipykernel_8748\3210457350.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   booked_data['total_nights_spend'] = booked_data['stays_in_week_nights'] + booked_data['stays_in_weekend_nights']

# %%
booked_data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card', 'total_nights_spend'],
#       dtype='object')

# %%
stay = booked_data.groupby(['total_nights_spend' , 'hotel']).count().reset_index()
stay
# Out:
#     total_nights_spend         hotel  is_canceled  lead_time  \
# 0                    0    City Hotel          251        251
# 1                    0  Resort Hotel          371        371
# 2                    1    City Hotel         9155       9155
# 3                    1  Resort Hotel         6579       6579
# 4                    2    City Hotel        10983      10983
# ..                 ...           ...          ...        ...
# 57                  46  Resort Hotel            1          1
# 58                  48    City Hotel            1          1
# 59                  56  Resort Hotel            1          1
# 60                  60  Resort Hotel            1          1
# 61                  69  Resort Hotel            1          1
#
#     arrival_date_year  arrival_date_month  arrival_date_week_number  \
# 0                 251                 251                       251
# 1                 371                 371                       371
# ...

# %%
stay = stay.iloc[:,0:3]
stay
# Out:
#     total_nights_spend         hotel  is_canceled
# 0                    0    City Hotel          251
# 1                    0  Resort Hotel          371
# 2                    1    City Hotel         9155
# 3                    1  Resort Hotel         6579
# 4                    2    City Hotel        10983
# ..                 ...           ...          ...
# 57                  46  Resort Hotel            1
# 58                  48    City Hotel            1
# 59                  56  Resort Hotel            1
# 60                  60  Resort Hotel            1
# 61                  69  Resort Hotel            1
#
# [62 rows x 3 columns]

# %%
stay = stay.rename(columns = {'is_canceled' : 'Number of People'})
stay
# Out:
#     total_nights_spend         hotel  Number of People
# 0                    0    City Hotel               251
# 1                    0  Resort Hotel               371
# 2                    1    City Hotel              9155
# 3                    1  Resort Hotel              6579
# 4                    2    City Hotel             10983
# ..                 ...           ...               ...
# 57                  46  Resort Hotel                 1
# 58                  48    City Hotel                 1
# 59                  56  Resort Hotel                 1
# 60                  60  Resort Hotel                 1
# 61                  69  Resort Hotel                 1
#
# [62 rows x 3 columns]

# %%
plt.figure(figsize = (18,8))
sns.barplot(x = 'total_nights_spend' , y = 'Number of People' , hue = 'hotel' , data = stay)
plt.title('Total Nights People Spend')
plt.show()

# %%
# getting data of guests who canceled their reservations for both hotels
canceled_data = new_data[new_data['is_canceled'] == 1]

# %%
canceled_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 108829    City Hotel            1         25               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %%
# total number of cancelations
canceled_data['is_canceled'].value_counts()
# Out:
# is_canceled
# 1    44199
# Name: count, dtype: int64

# %%
# total cancelations for both hotels
sns.countplot(x = 'is_canceled' , hue = 'hotel' , data = canceled_data)
plt.title('Number of Cancelations')
plt.show()

# %%
# total number of cancelations month wise 
month_cancelations = canceled_data['arrival_date_month'].value_counts().reset_index()
month_cancelations.columns = ['month' , 'number of cancelations']
month_to_num = { 'January' : 1 , 'February' : 2 , 'March' : 3 , 'April' : 4 , 'May' : 5 , 'June' : 6 , 'July' : 7 , 'August' : 8 , 'September' : 9 , 'October' : 10 , 'November' : 11 , 'December' : 12}
month_cancelations['month'] = month_cancelations['month'].map(month_to_num) 
month_cancelations
# Out:
#     month  number of cancelations
# 0       8                    5237
# 1       7                    4737
# 2       5                    4677
# 3       6                    4534
# 4       4                    4518
# 5      10                    4246
# 6       9                    4115
# 7       3                    3148
# 8       2                    2693
# 9      12                    2368
# 10     11                    2120
# 11      1                    1806

# %%
month_cancelations.sort_values('month' , ascending = True , inplace = True)

# %%
month_cancelations
# Out:
#     month  number of cancelations
# 11      1                    1806
# 8       2                    2693
# 7       3                    3148
# 4       4                    4518
# 2       5                    4677
# 3       6                    4534
# 1       7                    4737
# 0       8                    5237
# 6       9                    4115
# 5      10                    4246
# 10     11                    2120
# 9      12                    2368

# %%
# finding which month had the maximum cancelations
sns.barplot(x = 'month' , y = 'number of cancelations' , data = month_cancelations)
plt.title('Month wise Cancelations')
plt.show()

# %%
# saving cleaned data 
new_data.to_csv('Hotel_Bookings_cleaned.csv' , index = None)
